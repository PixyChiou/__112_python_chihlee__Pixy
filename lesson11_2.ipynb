# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/roberthsu2003/PythonForDataAnalysis/master/pandas%E7%9A%84%E6%AA%94%E6%A1%88%E5%AD%98%E5%8F%96/%E5%90%84%E9%84%89%E9%8E%AE%E5%B8%82%E5%8D%80%E4%BA%BA%E5%8F%A3%E5%AF%86%E5%BA%A6.csv'
dataFrame = pd.read_csv(url)

# %%
dataFrame
dataFrame.columns = dataFrame.iloc[0]
dataFrame1 = dataFrame.drop(index=0)
dataFrame2 = dataFrame1.drop(index=[371,372,373,374,375])
dataFrame2
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 369  106    東沙群島      …      2.38     …
# 370  106    南沙群島      …    0.5045     …
#
# [370 rows x 5 columns]

# %%
import psycopg2
from sqlalchemy import create_engine

engine = create_engine('postgres://pixy_user:PHq9ux21b7DzIxgckjvvWwVk7yz2rNUG@dpg-clc4vo7uj6oc738j3jk0-a.singapore-postgres.render.com/pixy')
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_sql.html
dataFrame2.to_sql('106年度人口密度',engine,if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# /workspaces/__112_python_chihlee__Pixy/lesson11_2.ipynb Cell 3 line 4
#       <a href='vscode-notebook-cell://codespaces%2Borganic-space-potato-979pqvg5jwxx2jqx/workspaces/__112_python_chihlee__Pixy/lesson11_2.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import psycopg2
#       <a href='vscode-notebook-cell://codespaces%2Borganic-space-potato-979pqvg5jwxx2jqx/workspaces/__112_python_chihlee__Pixy/lesson11_2.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from sqlalchemy import create_engine
# ----> <a href='vscode-notebook-cell://codespaces%2Borganic-space-potato-979pqvg5jwxx2jqx/workspaces/__112_python_chihlee__Pixy/lesson11_2.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> engine = create_engine('postgres://pixy_user:PHq9ux21b7DzIxgckjvvWwVk7yz2rNUG@dpg-clc4vo7uj6oc738j3jk0-a.singapore-postgres.render.com/pixy')
#       <a href='vscode-notebook-cell://codespaces%2Borganic-space-potato-979pqvg5jwxx2jqx/workspaces/__112_python_chihlee__Pixy/lesson11_2.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> #https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_sql.html
#       <a href='vscode-notebook-cell://codespaces%2Borganic-space-potato-979pqvg5jwxx2jqx/workspaces/__112_python_chihlee__Pixy/lesson11_2.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> dataFrame2.to_sql('106年度人口密度',engine,if_exists='replace')
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/create.py:552, in create_engine(url, **kwargs)
#     548 u = _url.make_url(url)
#     550 u, plugins, kwargs = u._instantiate_plugins(kwargs)
# --> 552 entrypoint = u._get_entrypoint()
#     553 _is_async = kwargs.pop("_is_async", False)
#     554 if _is_async:
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/url.py:754, in URL._get_entrypoint(self)
#     752 else:
#     753     name = self.drivername.replace("+", ".")
# --> 754 cls = registry.load(name)
#     755 # check for legacy dialects that
#     756 # would return a module with 'dialect' as the
#     757 # actual class
#     758 if (
#     759     hasattr(cls, "dialect")
#     760     and isinstance(cls.dialect, type)
#     761     and issubclass(cls.dialect, Dialect)
#     762 ):
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:374, in PluginLoader.load(self, name)
#     371         self.impls[name] = impl.load
#     372         return impl.load()
# --> 374 raise exc.NoSuchModuleError(
#     375     "Can't load plugin: %s:%s" % (self.group, name)
#     376 )
#
# NoSuchModuleError: Can't load plugin: sqlalchemy.dialects:postgres
